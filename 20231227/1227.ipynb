# %%
# 주석 커맨트
# 코드에 설명하는 용도  >> 필수로 해주는 것이 좋음 단 간결하게
# 프롬프트에 입력하여 직접 커맨드 입력 가능 
# >>> 

print("Hello~")
# Out:
# Hello~

# %% [markdown]
# <p style="color:red;"> 명령어 입력후 결과 확인 : 대화형 방식 </p>
# <p style="color:red;"> 파일 작성후 실행하는 방식: 스크립트 방식 </p>

# %%
# 종료 명령어
exit()

# %% [markdown]
# <h2>코딩 컨밴션</h2>
#
# <li>들여쓰기(Indentation)는 공백 4칸을 권장
# <li>한 줄은 최대 79자까지
# <li>클래스 내의 메소드 정의는 1줄 씩 띄어쓰기
# <li>주석은 항상 갱신, 불필요한 주석은 삭제
# <li>소문자 L, 대문자 O, 대문자 I는 변수명으로 사용하지 말 것 (가독성) (권장사항)
# <li>함수명은 소문자로 구성, 필요하면 밑줄로 나눔</li>
#
# <h2> 주석 작성 방법 </h2>
# <li> '''''' 로 작성

# %%
'''
여러줄 주석 작성 방식
IDE를 이용하면 편하지만 알고 있으면 좋음
'''
"""
쌍따움표도 주석 작성가능
"""
# Out:
# '\n쌍따움표도 주석 작성가능\n'

# %%
# 시키고 싶은 일 = 숫자 글자 데이터를 화면에 출력하기
# 출력하는 방법 print()
# 숫자 데이터 출력 (정수)

print(2024)
print(1227)
print(33)
print(1000)
# Out:
# 2024
# 1227
# 33
# 1000

# %%
# 숫자 데이터 중 실수
print(1.22)
print(123.12)
print(0.)
print(1.)
# Out:
# 1.22
# 123.12
# 0.0
# 1.0

# %%
# 문자 글자 문자열 데이터 출력 >> 글자 str
# print(홍길동) NameError: name '홍길동' is not defined
# "" 혹은 '' 를 사용하여 

print("홍길동")
print("happy new year")
print("1.")
# Out:
# 홍길동
# happy new year
# 1.

# %%
# 여러줄 문자열 만들기
print("""
good
    luck
with
""")

print(
    '''
    홑따음표도 사용가능함
    '''
)
# Out:
# good
#     luck
# with
#
#
#     홑따음표도 사용가능함

# %% [markdown]
# ![image.png](attachment:image.png)
# <br>
# 힙 영역 스택 영역이 메모리 문제의 원천 (오버플로우 등) <br>
# 파이선의 경우 해당 부분이 해결되어 있음 (객체 지향적) <br>
# Python Memory Manager 로 인해 관리되어 있음

# %% [markdown]
# ![image-2.png](attachment:image-2.png) <br>

# %% [markdown]
# <h3>변수의 이름 짓는 방법 </h3>
# <li>어떤 데이터가 저장되어 있는지 알 수 있도록 명명
# <li>문자, 숫자, 밑줄(_)만으로 변수 이름 구성
# <li>첫 문자로 숫자 사용 불가
# <li>대소문자 구분
# <li>예약어 사용 불가 </li>
#
# 파이선의 경우에는 heap의 데이터 영역에 변수를 저장하나 일부 언어에서는 스택에 직접 변수가 저장되기도 함(primary 변수인 경우)
#
# <br> 언어마다 저장되는 방식이 모두 다르기 때문에 상황에 맞게 분석 필요

# %%
'''
데이터를 메모리에 저장하는 방법에 대해서 살펴보자
=> 파이선에서의 문법 : "변수명 = 저장할 데이터"
파이썬의 변수는 힙영역에 저장된 데이터 주소를 저장하는 변수이다.
=> 참조 변수
'''

# 나이를 컴퓨터 메모리에 저장해보기
# => 나이 : 정수 int ==> 힙 영역
# => 변수 ==> age

age = 100
# 'age' = 100 X

# 이름을 메모리에 저장하기
# => 이름 : 문자 str ==> 힙 영역
# => 변수 ==> name


_name = '홍길동'
name = '홍길동'
# my name = '홍길동' X
# 99name = '홍길동' X
name99 = '홍길동'

# https://pythontutor.com/
# 위 예제는 해당 웹사이트를 통해서 visualize 가능하다

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
# 예약어 예시
# 해당 예약어는 변수로 사용할 수 없음

import keyword

print("Keyword \n", keyword.kwlist)
# Out:
# Keyword
#  ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
age = 12
name = "Hong"
female = "F"
average = 87.9
ok = False


# 아래 요소는 메모리에 저장은 되지만 위치를 알 수 없음
# 따라서 다시 사용할 수 없음
2024
"good luck"


# 위 내용을 사용하기 위해서 결국 변수에 저장하여야 함
year = 2024 
msg = "good luck"

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 데이터의 주소를 확인하는 내장 함수 => id(실제 데이터) / id(변수)

print(id(2024))
year = 2024
print(id(year))

# 주피터에서는 나타나지 않지만 위 예시는 같은 id 를 가진다.
# id_heap_relation.py 파일로 정확하게 확인 가능합니다.
# Out:
# 1867737060624
# 1867737060208

# %%
print(id(2024))
year = 2024
print(id(year))
year = 2023
print(id(year))


# 기존 언어의 경우 저장하고자 하는 type을 생각하여야하나
# 파이선의 경우 자동으로 type을 결정 하는 것(동적 메모리 할당)
# Out:
# 1867762850832
# 1867762777712
# 1867762775056

# %% [markdown]
# ![image.png](attachment:image.png)<br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 변수가 저장하고 있는 데이터의 종류 즉, 데이터 타입을
# 알려주는 함수 >> type()

print(type(2024))
print(type(2024.))
print(type('2024'))
print(type('4.'))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ![image.png](attachment:image.png) <br>

# %%
'''
출력기능의 내장 함수 print()
'''

# 1개 데이터 화면 출력
print(100)
# 2개 데이터 화면 출력
print(100,200)
print(100, "Good Luck")

# 따라서 여러개 데이터 출력시 ,로 구분

print("abc", 5., "1000", "Happy New Year")


# 만약 데이터가 없을 경우에는 화면 출력
print()
# Out:
# 100
# 100 200
# 100 Good Luck
# abc 5.0 1000 Happy New Year

# %%
# print의 다양한 출력 방법
# 데이터 출력을 좀 더 다양하게 하는 방법들
# 출력대상 : 

print('오늘은 2024년 12월 27일 입니다.')

year = 2024
month = 12
day = 27

# print("오늘은", year, "년 ", month, "월 ", day, "일 ")
print("오늘은 %d년 %d월 %d일 입니다."%(year, month, day))
print("오늘은 {}년 {}월 {}일 입니다.".format(year, month, day))
print(f"오늘은 {year}년 {month}월 {day}일 입니다.")
# Out:
# 오늘은 2024년 12월 27일 입니다.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 12
#       9 day = 27
#      11 # print("오늘은", year, "년 ", month, "월 ", day, "일 ")
# ---> 12 print("오늘은 %s년 %s월 %일 입니다."%(year, month, day))
#      13 print("오늘은 {}년 {}월 {}일 입니다.".format(year, month, day))
#      14 print(f"오늘은 {year}년 {month}월 {day}일 입니다.")
#
# ValueError: unsupported format character '?' (0xc77c) at index 13
